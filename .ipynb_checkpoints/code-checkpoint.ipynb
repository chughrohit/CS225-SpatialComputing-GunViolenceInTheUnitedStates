# %% [markdown]
# # Import Libraries

# %%
# %%capture
# !pip3 install numpy pandas

# %%
import numpy as np, pandas as pd
import math
import os

# %% [markdown]
# ## Graph Plotting Libraries

# %%
# %%capture
# !pip3 install matplotlib seaborn plotly

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly
plotly.offline.init_notebook_mode (connected = True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %% [markdown]
# ### Calendar Heapmap

# %%
# %%capture
# !pip3 install calmap
import calmap

# %% [markdown]
# ### Geospatial libraries

# %%
# %%capture
# !pip3 install geopandas geopy folium

# %%
import geopandas as gpd
import folium
from folium import Choropleth, Circle, Marker
from folium.plugins import HeatMap, MarkerCluster
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter

# %%
# %matplotlib inline

# %% [markdown]
# # Load Dataset

# %% [markdown]
# ## Load Shooting data

# %%
df = pd.read_csv('data/fatal-police-shootings-data.csv', parse_dates=['date'])
df.head()
# Out:
#    id                name       date   manner_of_death       armed   age  \
# 0   3          Tim Elliot 2015-01-02              shot         gun  53.0
# 1   4    Lewis Lee Lembke 2015-01-02              shot         gun  47.0
# 2   5  John Paul Quintero 2015-01-03  shot and Tasered     unarmed  23.0
# 3   8     Matthew Hoffman 2015-01-04              shot  toy weapon  32.0
# 4   9   Michael Rodriguez 2015-01-04              shot    nail gun  39.0
#
#   gender race           city state  signs_of_mental_illness threat_level  \
# 0      M    A        Shelton    WA                     True       attack
# 1      M    W          Aloha    OR                    False       attack
# 2      M    H        Wichita    KS                    False        other
# 3      M    W  San Francisco    CA                     True       attack
# 4      M    H          Evans    CO                    False       attack
#
#           flee  body_camera
# 0  Not fleeing        False
# 1  Not fleeing        False
# 2  Not fleeing        False
# 3  Not fleeing        False
# 4  Not fleeing        False

# %% [markdown]
# ## Load City Data

# %%
city = pd.read_csv("data/cities.csv")

# %%
city.head()
# Out:
#    Unnamed: 0           city state               address  \
# 0           0        Shelton    WA        Shelton,WA,USA
# 1           1          Aloha    OR          Aloha,OR,USA
# 2           2        Wichita    KS        Wichita,KS,USA
# 3           3  San Francisco    CA  San Francisco,CA,USA
# 4           4          Evans    CO          Evans,CO,USA
#
#                          geom   latitude   longitude
# 0  (47.2150945, -123.1007066)  47.215094 -123.100707
# 1  (45.4942838, -122.8670451)  45.494284 -122.867045
# 2   (37.6922361, -97.3375448)  37.692236  -97.337545
# 3  (37.7790262, -122.4199061)  37.779026 -122.419906
# 4  (40.3763701, -104.6921874)  40.376370 -104.692187

# %%
city.drop(["Unnamed: 0","geom","address"], axis=1, inplace=True)

# %% [markdown]
# ## Merge City Data (latitude, longitude) with shooting dataset

# %%
df_city = pd.merge(df, city, on=["city","state"])

# %%
df_city.head()
# Out:
#      id                  name       date   manner_of_death    armed   age  \
# 0     3            Tim Elliot 2015-01-02              shot      gun  53.0
# 1  5685       Kathryn R. Hale 2020-03-24              shot  vehicle  32.0
# 2     4      Lewis Lee Lembke 2015-01-02              shot      gun  47.0
# 3   890  Phyllis Ilene Jepsen 2015-10-02              shot    knife  55.0
# 4     5    John Paul Quintero 2015-01-03  shot and Tasered  unarmed  23.0
#
#   gender race     city state  signs_of_mental_illness threat_level  \
# 0      M    A  Shelton    WA                     True       attack
# 1      F    W  Shelton    WA                    False       attack
# 2      M    W    Aloha    OR                    False       attack
# 3      F    W    Aloha    OR                     True        other
# 4      M    H  Wichita    KS                    False        other
#
#           flee  body_camera   latitude   longitude
# 0  Not fleeing        False  47.215094 -123.100707
# 1          Car        False  47.215094 -123.100707
# 2  Not fleeing        False  45.494284 -122.867045
# 3  Not fleeing        False  45.494284 -122.867045
# 4  Not fleeing        False  37.692236  -97.337545

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ## See Datatypes

# %%
df_city.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5388 entries, 0 to 5387
# Data columns (total 16 columns):
# id                         5388 non-null int64
# name                       5388 non-null object
# date                       5388 non-null datetime64[ns]
# manner_of_death            5388 non-null object
# armed                      5163 non-null object
# age                        5154 non-null float64
# gender                     5386 non-null object
# race                       4871 non-null object
# city                       5388 non-null object
# state                      5388 non-null object
# signs_of_mental_illness    5388 non-null bool
# threat_level               5388 non-null object
# flee                       5139 non-null object
# body_camera                5388 non-null bool
# latitude                   5388 non-null float64
# longitude                  5388 non-null float64
# dtypes: bool(2), datetime64[ns](1), float64(3), int64(1), object(9)
# memory usage: 641.9+ KB

# %% [markdown]
# ## Check if null values exists

# %%
df_city.isnull().sum()
# Out:
# id                           0
# name                         0
# date                         0
# manner_of_death              0
# armed                      225
# age                        234
# gender                       2
# race                       517
# city                         0
# state                        0
# signs_of_mental_illness      0
# threat_level                 0
# flee                       249
# body_camera                  0
# latitude                     0
# longitude                    0
# dtype: int64

# %% [markdown]
# ## Drop rows with null values

# %%
df_city = df_city.dropna(axis=0)
df_city.isnull().sum()
# Out:
# id                         0
# name                       0
# date                       0
# manner_of_death            0
# armed                      0
# age                        0
# gender                     0
# race                       0
# city                       0
# state                      0
# signs_of_mental_illness    0
# threat_level               0
# flee                       0
# body_camera                0
# latitude                   0
# longitude                  0
# dtype: int64

# %%
df_city.head()
# Out:
#      id                  name       date   manner_of_death    armed   age  \
# 0     3            Tim Elliot 2015-01-02              shot      gun  53.0
# 1  5685       Kathryn R. Hale 2020-03-24              shot  vehicle  32.0
# 2     4      Lewis Lee Lembke 2015-01-02              shot      gun  47.0
# 3   890  Phyllis Ilene Jepsen 2015-10-02              shot    knife  55.0
# 4     5    John Paul Quintero 2015-01-03  shot and Tasered  unarmed  23.0
#
#   gender race     city state  signs_of_mental_illness threat_level  \
# 0      M    A  Shelton    WA                     True       attack
# 1      F    W  Shelton    WA                    False       attack
# 2      M    W    Aloha    OR                    False       attack
# 3      F    W    Aloha    OR                     True        other
# 4      M    H  Wichita    KS                    False        other
#
#           flee  body_camera   latitude   longitude
# 0  Not fleeing        False  47.215094 -123.100707
# 1          Car        False  47.215094 -123.100707
# 2  Not fleeing        False  45.494284 -122.867045
# 3  Not fleeing        False  45.494284 -122.867045
# 4  Not fleeing        False  37.692236  -97.337545

# %% [markdown]
# # Data Exploration and Spatial Analysis

# %% [markdown]
# ## Time Series Spread of Incidents

# %%
df_group_by_date = df.groupby(df["date"])
count_by_date = df_group_by_date["id"].count()

# %% [markdown]
# ### Plot on calendar map

# %%
fig, ax = calmap.calendarplot(count_by_date, monthticks=1,fillcolor='whitesmoke', daylabels='MTWTFSS', linewidth=1, yearlabels=1, yearlabel_kws = dict(color='black'), fig_kws=dict(figsize=(20,20)))
fig.colorbar(ax[0].get_children()[1], ax=ax.ravel().tolist())

# %% [markdown]
# ## Geospatial Analysis

# %%
df_group_by_state = df['state'].value_counts()

df_states = pd.DataFrame()
df_states['state'] = df_group_by_state.index
df_states['count'] = df_group_by_state.values

# %% [markdown]
# ### Map Plot - Total Numbe of Incidents by State

# %%
from plotly.offline import iplot

state_to_code = {
    "AL": "Alabama",
    "AK": "Alaska",
    "AS": "American Samoa",
    "AZ": "Arizona",
    "AR": "Arkansas",
    "CA": "California",
    "CO": "Colorado",
    "CT": "Connecticut",
    "DE": "Delaware",
    "DC": "District Of Columbia",
    "FM": "Federated States Of Micronesia",
    "FL": "Florida",
    "GA": "Georgia",
    "GU": "Guam",
    "HI": "Hawaii",
    "ID": "Idaho",
    "IL": "Illinois",
    "IN": "Indiana",
    "IA": "Iowa",
    "KS": "Kansas",
    "KY": "Kentucky",
    "LA": "Louisiana",
    "ME": "Maine",
    "MH": "Marshall Islands",
    "MD": "Maryland",
    "MA": "Massachusetts",
    "MI": "Michigan",
    "MN": "Minnesota",
    "MS": "Mississippi",
    "MO": "Missouri",
    "MT": "Montana",
    "NE": "Nebraska",
    "NV": "Nevada",
    "NH": "New Hampshire",
    "NJ": "New Jersey",
    "NM": "New Mexico",
    "NY": "New York",
    "NC": "North Carolina",
    "ND": "North Dakota",
    "MP": "Northern Mariana Islands",
    "OH": "Ohio",
    "OK": "Oklahoma",
    "OR": "Oregon",
    "PW": "Palau",
    "PA": "Pennsylvania",
    "PR": "Puerto Rico",
    "RI": "Rhode Island",
    "SC": "South Carolina",
    "SD": "South Dakota",
    "TN": "Tennessee",
    "TX": "Texas",
    "UT": "Utah",
    "VT": "Vermont",
    "VI": "Virgin Islands",
    "VA": "Virginia",
    "WA": "Washington",
    "WV": "West Virginia",
    "WI": "Wisconsin",
    "WY": "Wyoming"
}

df_states['state_code'] = df_states['state'].apply(lambda x : state_to_code[x])

data = [ dict(
        type='choropleth',
        locations = df_states['state'],
        locationmode = 'USA-states',
        colorscale = 'Reds',
        text = df_states['state_code'],
        z = df_states['count'],
        colorbar = dict(
                title = "Gun Violence Incidents")
        ) ]

layout = dict(
        title = 'State wise number of Gun Violence Incidents',
        geo = dict(scope='usa'))

choromap = go.Figure(data=data, layout=layout)
iplot(choromap)
# Out:
# <div>                            <div id="cb46e7e1-c803-4d28-a6aa-fce8e4f0ed0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("cb46e7e1-c803-4d28-a6aa-fce8e4f0ed0c")) {                    Plotly.newPlot(                        "cb46e7e1-c803-4d28-a6aa-fce8e4f0ed0c",                        [{"colorbar": {"title": {"text": "Gun Violence Incidents"}}, "colorscale": [[0.0, "rgb(255,245,240)"], [0.125, "rgb(254,224,210)"], [0.25, "rgb(252,187,161)"], [0.375, "rgb(252,146,114)"], [0.5, "rgb(251,106,74)"], [0.625, "rgb(239,59,44)"], [0.75, "rgb(203,24,29)"], [0.875, "rgb(165,15,21)"], [1.0, "rgb(103,0,13)"]], "locationmode": "USA-states", "locations": ["CA", "TX", "FL", "AZ", "CO", "GA", "OK", "NC", "OH", "WA", "MO", "TN", "LA", "PA", "NM", "AL", "IL", "NY", "NV", "VA", "KY", "IN", "WI", "SC", "OR", "AR", "MD", "MI", "NJ", "MS", "MN", "UT", "WV", "KS", "ID", "AK", "MA", "IA", "MT", "HI", "NE", "ME", "CT", "SD", "WY", "DE", "NH", "DC", "ND", "VT", "RI"], "text": ["California", "Texas", "Florida", "Arizona", "Colorado", "Georgia", "Oklahoma", "North Carolina", "Ohio", "Washington", "Missouri", "Tennessee", "Louisiana", "Pennsylvania", "New Mexico", "Alabama", "Illinois", "New York", "Nevada", "Virginia", "Kentucky", "Indiana", "Wisconsin", "South Carolina", "Oregon", "Arkansas", "Maryland", "Michigan", "New Jersey", "Mississippi", "Minnesota", "Utah", "West Virginia", "Kansas", "Idaho", "Alaska", "Massachusetts", "Iowa", "Montana", "Hawaii", "Nebraska", "Maine", "Connecticut", "South Dakota", "Wyoming", "Delaware", "New Hampshire", "District Of Columbia", "North Dakota", "Vermont", "Rhode Island"], "type": "choropleth", "z": [799, 481, 350, 254, 195, 182, 164, 156, 155, 152, 141, 139, 109, 108, 106, 104, 104, 101, 96, 95, 95, 95, 91, 88, 88, 83, 79, 78, 68, 65, 61, 60, 54, 50, 42, 39, 35, 32, 31, 30, 24, 22, 21, 17, 14, 13, 13, 13, 11, 9, 4]}],                        {"geo": {"scope": "usa"}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.77777777 ...

# %% [markdown]
# ## Scatter Plot - Incident Locations in US

# %%
df_city['incident_counts'] = df_city['id'].groupby(df_city['state']).transform('count')

data = [go.Scattergeo(
    lon = df_city['longitude'],
    lat = df_city['latitude'],
    text = df_city['state'],
    mode = 'markers',
    marker = dict(symbol='star', size=5, colorscale='Reds'),
    marker_color = df_city['incident_counts'],
)]

layout = dict(title='Incident Locations in US Map', geo_scope='usa')

choromap = go.Figure(data=data, layout=layout)
iplot(choromap)
# Out:
# <div>                            <div id="32b82906-3c4b-43b6-a06a-f6c2d0bf3b0e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("32b82906-3c4b-43b6-a06a-f6c2d0bf3b0e")) {                    Plotly.newPlot(                        "32b82906-3c4b-43b6-a06a-f6c2d0bf3b0e",                        [{"lat": [47.2150945, 47.2150945, 45.4942838, 45.4942838, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.6922361, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 37.779026200000004, 40.3763701, 40.3763701, 35.8789231, 35.8789231, 33.3062223, 33.3062223, 33.3062223, 33.3062223, 33.3062223, 38.6802826, 40.8075391, 40.8075391, 40.414041, 37.9577016, 37.9577016, 37.9577016, 37.9577016, 37.9577016, 37.9577016, 37.9577016, 28.9541368, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 39.9622601, 41.5910641, 41.5910641, 41.5910641, 41.5910641, 29.949932300000004, 29.949932300000004, 29.949932300000004, 29.949932300000004, 29.949932300000004, 29.949932300000004, 29.949932300000004, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 40.759619799999996, 33.1103602, 41.089593799999996, 34.5442609, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 31.7754152, 39.684754999999996, 33.9463456, 33.9463456, 33.9463456, 33.9463456, 36.2005843, 36.2005843, 36.2005843, 36.2005843, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 35.0841034, 28.918029399999998, 44.9504037, 44.9504037, 44.9504037, 44.9504037, 44.9504037, 44.9504037, 44.9504037, 44.9504037, 36.718370799999995, 36.718370799999995, 40.399178000000006, 29.0338575, 29.0338575, 29.0338575, 29.0338575, 40.5246711, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.7683331, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 39.729432, 44.832240500000005, 38.2493581, 30.697677600000002, 32.3665322, 37.548269700000006, 37.548269700000006, 37.548269700000006, 37.548269700000006, 35.6630196, 35.6630196, 35.6630196, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536909, 34.0536 ...

# %% [markdown]
# ## Compare Indicents For Months (Jan-Feb) by Year

# %% [markdown]
# ### Filter Data for Jan-Feb

# %%
df_city_2015 = df_city[(df_city['date'] >= '2015-01-01') & (df_city['date'] <= '2015-06-10')]
df_city_2016 = df_city[(df_city['date'] >= '2016-01-01') & (df_city['date'] <= '2016-06-10')]
df_city_2017 = df_city[(df_city['date'] >= '2017-01-01') & (df_city['date'] <= '2017-06-10')]
df_city_2018 = df_city[(df_city['date'] >= '2018-01-01') & (df_city['date'] <= '2018-06-10')]
df_city_2019 = df_city[(df_city['date'] >= '2019-01-01') & (df_city['date'] <= '2019-06-10')]

# %% [markdown]
# ### Count Indicents for filtered data

# %%
df_city_2015_monthly = df_city_2015['date'].groupby([df_city_2015['date'].dt.month.rename('month')]).agg({'count'})
df_city_2016_monthly = df_city_2016['date'].groupby([df_city_2016['date'].dt.month.rename('month')]).agg({'count'})
df_city_2017_monthly = df_city_2017['date'].groupby([df_city_2017['date'].dt.month.rename('month')]).agg({'count'})
df_city_2018_monthly = df_city_2018['date'].groupby([df_city_2018['date'].dt.month.rename('month')]).agg({'count'})
df_city_2019_monthly = df_city_2019['date'].groupby([df_city_2019['date'].dt.month.rename('month')]).agg({'count'})

# %% [markdown]
# ### Plot monthly data

# %%
months = {
    1 : "Jan",
    2 : "Feb",
    3 : "Mar",
    4 : "Apr",
    5 : "May",
    6 : "Jun"
}


label = 2015
for frame in [df_city_2015_monthly, df_city_2016_monthly, df_city_2017_monthly, df_city_2018_monthly, df_city_2019_monthly]:
    plt.plot([months[idx] for idx in frame.index], \
             frame['count'], label=str(label))
    label += 1

plt.legend(loc="upper right")
plt.grid(b=True, which='major', color='grey', linestyle='dashdot')

plt.title("Gun Violence From Jan - June for Years 2015 - 2019")
plt.xticks(range(0, 6))
plt.xlabel('Number of Incidents', fontsize=20)
plt.ylabel('Months', fontsize=20)

plt.rcParams["figure.figsize"] = (20,10)
plt.show()
